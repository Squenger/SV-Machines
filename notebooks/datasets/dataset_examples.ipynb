# %%
# %load_ext autoreload
# %autoreload 2

# Local imports
from sv_machines.datasets.circle import get_circle_dataset, get_circle_plot
from sv_machines.datasets.line import get_line_dataset, get_line_plot

# %% [markdown]
# # Line dataset

# %%
slope, offset, epsilon = 2.0, 1.5, 1.5

x_line, y_line = get_line_dataset(slope=slope, offset= offset, epsilon=epsilon, num_points=500, epsilon_strict=True)

fig, ax = get_line_plot(x_line, y_line, slope= slope, offset= offset, epsilon= epsilon, with_true_function=True)
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# # Circle dataset

# %%
radius, epsilon = 5.0, 0.5

x_circle, y_circle = get_circle_dataset(radius=radius, epsilon=epsilon, num_points=500, epsilon_strict=True)

fig, ax = get_circle_plot(x_circle, y_circle, radius= radius, epsilon= epsilon, with_true_function=True)
fig.legend(loc='center left', bbox_to_anchor=(1, 0.5))
